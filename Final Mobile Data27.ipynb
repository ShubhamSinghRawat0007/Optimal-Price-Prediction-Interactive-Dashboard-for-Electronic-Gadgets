# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('smartphones_data.csv')

# %%
df.head(5)
# Out:
#   brand_name                      Name   Price   RAM       OS  storage  \
# 0       vivo                  vivo v50   34999   8.0  android    128.0
# 1     realme             realme p3 pro   21999   8.0  android    128.0
# 2     realme        realme 14 pro plus   27999   8.0  android    128.0
# 3    samsung  samsung galaxy s25 ultra  129999  12.0  android    256.0
# 4       vivo               vivo t3 pro   22999   8.0  android    128.0
#
#    Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0         6000               Yes              Yes      No    Yes
# 1         6000               Yes              Yes      No    Yes
# 2         6000               Yes              Yes      No    Yes
# 3         5000               Yes              Yes     Yes    Yes
# 4         5500               Yes              Yes      No    Yes
#
#   processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon       8.0                 50.0                 2
# 1      snapdragon       8.0                 50.0                 2
# 2      snapdragon       8.0                 50.0                 3
# 3      snapdragon       8.0                200.0                 4
# 4      snapdragon       8.0                 50.0                 2
#
#    primery_front_camera  num_front_camera  display_size(inch)  \
# 0                  50.0                 1                6.77
# 1                  16.0                 1                6.83
# 2                  32.0                 1                6.83
# 3                  12.0                 1                6.90
# 4                  16.0                 1                6.77
#
#    refresh_rate(hz)   display_types
# 0             120.0  amoled display
# 1             120.0  amoled display
# 2             120.0    oled display
# 3             120.0  amoled display
# 4             120.0  amoled display

# %%
df.shape
# Out:
# (3260, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3260 entries, 0 to 3259
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            3260 non-null   object
#  1   Name                  3260 non-null   object
#  2   Price                 3260 non-null   int64
#  3   RAM                   3260 non-null   float64
#  4   OS                    3260 non-null   object
#  5   storage               3260 non-null   float64
#  6   Battery_cap           3260 non-null   int64
#  7   has_fast_charging     3260 non-null   object
#  8   has_fingerprints      2534 non-null   object
#  9   has_nfc               2534 non-null   object
#  10  has_5g                2534 non-null   object
#  11  processor_brand       3260 non-null   object
#  12  num_core              3085 non-null   float64
#  13  primery_rear_camera   3260 non-null   float64
#  14  Num_Rear_Cameras      3260 non-null   int64
#  15  primery_front_camera  3260 non-null   float64
#  16  num_front_camera      3260 non-null   int64
#  17  display_size(inch)    3260 non-null   float64
#  18  refresh_rate(hz)      1529 non-null   float64
#  19  display_types         3260 non-null   object
# dtypes: float64(7), int64(4), object(9)
# memory usage: 509.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# brand_name                 0
# Name                       0
# Price                      0
# RAM                        0
# OS                         0
# storage                    0
# Battery_cap                0
# has_fast_charging          0
# has_fingerprints         726
# has_nfc                  726
# has_5g                   726
# processor_brand            0
# num_core                 175
# primery_rear_camera        0
# Num_Rear_Cameras           0
# primery_front_camera       0
# num_front_camera           0
# display_size(inch)         0
# refresh_rate(hz)        1731
# display_types              0
# dtype: int64

# %%
df.head(5)
# Out:
#   brand_name                      Name   Price   RAM       OS  storage  \
# 0       vivo                  vivo v50   34999   8.0  android    128.0
# 1     realme             realme p3 pro   21999   8.0  android    128.0
# 2     realme        realme 14 pro plus   27999   8.0  android    128.0
# 3    samsung  samsung galaxy s25 ultra  129999  12.0  android    256.0
# 4       vivo               vivo t3 pro   22999   8.0  android    128.0
#
#    Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0         6000               Yes              Yes      No    Yes
# 1         6000               Yes              Yes      No    Yes
# 2         6000               Yes              Yes      No    Yes
# 3         5000               Yes              Yes     Yes    Yes
# 4         5500               Yes              Yes      No    Yes
#
#   processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon       8.0                 50.0                 2
# 1      snapdragon       8.0                 50.0                 2
# 2      snapdragon       8.0                 50.0                 3
# 3      snapdragon       8.0                200.0                 4
# 4      snapdragon       8.0                 50.0                 2
#
#    primery_front_camera  num_front_camera  display_size(inch)  \
# 0                  50.0                 1                6.77
# 1                  16.0                 1                6.83
# 2                  32.0                 1                6.83
# 3                  12.0                 1                6.90
# 4                  16.0                 1                6.77
#
#    refresh_rate(hz)   display_types
# 0             120.0  amoled display
# 1             120.0  amoled display
# 2             120.0    oled display
# 3             120.0  amoled display
# 4             120.0  amoled display

# %%
df.drop(columns=['refresh_rate(hz)'],inplace=True)

# %%
df.head(4)
# Out:
#   brand_name                      Name   Price   RAM       OS  storage  \
# 0       vivo                  vivo v50   34999   8.0  android    128.0
# 1     realme             realme p3 pro   21999   8.0  android    128.0
# 2     realme        realme 14 pro plus   27999   8.0  android    128.0
# 3    samsung  samsung galaxy s25 ultra  129999  12.0  android    256.0
#
#    Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0         6000               Yes              Yes      No    Yes
# 1         6000               Yes              Yes      No    Yes
# 2         6000               Yes              Yes      No    Yes
# 3         5000               Yes              Yes     Yes    Yes
#
#   processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon       8.0                 50.0                 2
# 1      snapdragon       8.0                 50.0                 2
# 2      snapdragon       8.0                 50.0                 3
# 3      snapdragon       8.0                200.0                 4
#
#    primery_front_camera  num_front_camera  display_size(inch)   display_types
# 0                  50.0                 1                6.77  amoled display
# 1                  16.0                 1                6.83  amoled display
# 2                  32.0                 1                6.83    oled display
# 3                  12.0                 1                6.90  amoled display

# %%
df.isnull().sum()
# Out:
# brand_name                0
# Name                      0
# Price                     0
# RAM                       0
# OS                        0
# storage                   0
# Battery_cap               0
# has_fast_charging         0
# has_fingerprints        726
# has_nfc                 726
# has_5g                  726
# processor_brand           0
# num_core                175
# primery_rear_camera       0
# Num_Rear_Cameras          0
# primery_front_camera      0
# num_front_camera          0
# display_size(inch)        0
# display_types             0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# Create an imputer with strategy 'most_frequent'
imputer = SimpleImputer(strategy='most_frequent')

# List of columns to impute (replace with actual column names)
columns_to_impute = ['has_fingerprints', 'has_nfc', 'has_5g','num_core']  # Replace with actual column names

# Apply imputer to the selected columns
df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

# %%
df.isnull().sum()
# Out:
# brand_name              0
# Name                    0
# Price                   0
# RAM                     0
# OS                      0
# storage                 0
# Battery_cap             0
# has_fast_charging       0
# has_fingerprints        0
# has_nfc                 0
# has_5g                  0
# processor_brand         0
# num_core                0
# primery_rear_camera     0
# Num_Rear_Cameras        0
# primery_front_camera    0
# num_front_camera        0
# display_size(inch)      0
# display_types           0
# dtype: int64

# %%
df.head(5)
# Out:
#   brand_name                      Name   Price   RAM       OS  storage  \
# 0       vivo                  vivo v50   34999   8.0  android    128.0
# 1     realme             realme p3 pro   21999   8.0  android    128.0
# 2     realme        realme 14 pro plus   27999   8.0  android    128.0
# 3    samsung  samsung galaxy s25 ultra  129999  12.0  android    256.0
# 4       vivo               vivo t3 pro   22999   8.0  android    128.0
#
#    Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0         6000               Yes              Yes      No    Yes
# 1         6000               Yes              Yes      No    Yes
# 2         6000               Yes              Yes      No    Yes
# 3         5000               Yes              Yes     Yes    Yes
# 4         5500               Yes              Yes      No    Yes
#
#   processor_brand num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon      8.0                 50.0                 2
# 1      snapdragon      8.0                 50.0                 2
# 2      snapdragon      8.0                 50.0                 3
# 3      snapdragon      8.0                200.0                 4
# 4      snapdragon      8.0                 50.0                 2
#
#    primery_front_camera  num_front_camera  display_size(inch)   display_types
# 0                  50.0                 1                6.77  amoled display
# 1                  16.0                 1                6.83  amoled display
# 2                  32.0                 1                6.83    oled display
# 3                  12.0                 1                6.90  amoled display
# 4                  16.0                 1                6.77  amoled display

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3260 entries, 0 to 3259
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            3260 non-null   object
#  1   Name                  3260 non-null   object
#  2   Price                 3260 non-null   int64
#  3   RAM                   3260 non-null   float64
#  4   OS                    3260 non-null   object
#  5   storage               3260 non-null   float64
#  6   Battery_cap           3260 non-null   int64
#  7   has_fast_charging     3260 non-null   object
#  8   has_fingerprints      3260 non-null   object
#  9   has_nfc               3260 non-null   object
#  10  has_5g                3260 non-null   object
#  11  processor_brand       3260 non-null   object
#  12  num_core              3260 non-null   object
#  13  primery_rear_camera   3260 non-null   float64
#  14  Num_Rear_Cameras      3260 non-null   int64
#  15  primery_front_camera  3260 non-null   float64
#  16  num_front_camera      3260 non-null   int64
#  17  display_size(inch)    3260 non-null   float64
#  18  display_types         3260 non-null   object
# dtypes: float64(5), int64(4), object(10)
# memory usage: 484.0+ KB

# %%
# List of columns to convert to integers
columns_to_convert = ['RAM', 'storage', 'primery_rear_camera','num_core','primery_front_camera']  # Replace with actual column names

# Convert columns to integer type
df[columns_to_convert] = df[columns_to_convert].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3260 entries, 0 to 3259
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            3260 non-null   object
#  1   Name                  3260 non-null   object
#  2   Price                 3260 non-null   int64
#  3   RAM                   3260 non-null   int64
#  4   OS                    3260 non-null   object
#  5   storage               3260 non-null   int64
#  6   Battery_cap           3260 non-null   int64
#  7   has_fast_charging     3260 non-null   object
#  8   has_fingerprints      3260 non-null   object
#  9   has_nfc               3260 non-null   object
#  10  has_5g                3260 non-null   object
#  11  processor_brand       3260 non-null   object
#  12  num_core              3260 non-null   int64
#  13  primery_rear_camera   3260 non-null   int64
#  14  Num_Rear_Cameras      3260 non-null   int64
#  15  primery_front_camera  3260 non-null   int64
#  16  num_front_camera      3260 non-null   int64
#  17  display_size(inch)    3260 non-null   float64
#  18  display_types         3260 non-null   object
# dtypes: float64(1), int64(9), object(9)
# memory usage: 484.0+ KB

# %%
df.head(5)
# Out:
#   brand_name                      Name   Price  RAM       OS  storage  \
# 0       vivo                  vivo v50   34999    8  android      128
# 1     realme             realme p3 pro   21999    8  android      128
# 2     realme        realme 14 pro plus   27999    8  android      128
# 3    samsung  samsung galaxy s25 ultra  129999   12  android      256
# 4       vivo               vivo t3 pro   22999    8  android      128
#
#    Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0         6000               Yes              Yes      No    Yes
# 1         6000               Yes              Yes      No    Yes
# 2         6000               Yes              Yes      No    Yes
# 3         5000               Yes              Yes     Yes    Yes
# 4         5500               Yes              Yes      No    Yes
#
#   processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon         8                   50                 2
# 1      snapdragon         8                   50                 2
# 2      snapdragon         8                   50                 3
# 3      snapdragon         8                  200                 4
# 4      snapdragon         8                   50                 2
#
#    primery_front_camera  num_front_camera  display_size(inch)   display_types
# 0                    50                 1                6.77  amoled display
# 1                    16                 1                6.83  amoled display
# 2                    32                 1                6.83    oled display
# 3                    12                 1                6.90  amoled display
# 4                    16                 1                6.77  amoled display

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['brand_name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='brand_name'>

# %%
sns.barplot(x=df['brand_name'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['display_size(inch)'])
# Out:
# <Axes: xlabel='display_size(inch)', ylabel='Density'>

# %%
sns.scatterplot(x=df['display_size(inch)'],y=df['Price'])
# Out:
# <Axes: xlabel='display_size(inch)', ylabel='Price'>

# %%
df.head(5)
# Out:
#   brand_name                      Name   Price  RAM       OS  storage  \
# 0       vivo                  vivo v50   34999    8  android      128
# 1     realme             realme p3 pro   21999    8  android      128
# 2     realme        realme 14 pro plus   27999    8  android      128
# 3    samsung  samsung galaxy s25 ultra  129999   12  android      256
# 4       vivo               vivo t3 pro   22999    8  android      128
#
#    Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0         6000               Yes              Yes      No    Yes
# 1         6000               Yes              Yes      No    Yes
# 2         6000               Yes              Yes      No    Yes
# 3         5000               Yes              Yes     Yes    Yes
# 4         5500               Yes              Yes      No    Yes
#
#   processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon         8                   50                 2
# 1      snapdragon         8                   50                 2
# 2      snapdragon         8                   50                 3
# 3      snapdragon         8                  200                 4
# 4      snapdragon         8                   50                 2
#
#    primery_front_camera  num_front_camera  display_size(inch)   display_types
# 0                    50                 1                6.77  amoled display
# 1                    16                 1                6.83  amoled display
# 2                    32                 1                6.83    oled display
# 3                    12                 1                6.90  amoled display
# 4                    16                 1                6.77  amoled display

# %%
df['OS'].value_counts()
# Out:
# OS
# android    3130
# ios         120
# other        10
# Name: count, dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# mediatek        1384
# snapdragon      1055
# quad             186
# unisoc           176
# samsung          144
# apple            120
# spreadtrum        85
# hisilicon         37
# tru-mediatek      33
# google            15
# intel             15
# broadcom           7
# st-ericsson        1
# nvidia             1
# huawei             1
# Name: count, dtype: int64

# %%
# Cluster 'processor_brand' into Snapdragon, Apple, and Others
def cluster_processor(brand):
    Snapdragon = ['snapdragon', 'samsung', 'quad','google']
    Apple = ['apple']
    Mediatek = ['mediatek','tru-mediatek']
    others = ['unisoc','spreadtrum','hisilicon','intel','broadcom','st-ericsson','nvidia','huawei']
    
    if brand in Snapdragon:
        return 'Snapdragon'
    elif brand in Apple:
        return 'Apple'
    elif brand in Mediatek:
        return 'Mediatek'
    else:
        return 'Others'

df['processor_cluster'] = df['processor_brand'].apply(cluster_processor)

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# mediatek        1384
# snapdragon      1055
# quad             186
# unisoc           176
# samsung          144
# apple            120
# spreadtrum        85
# hisilicon         37
# tru-mediatek      33
# google            15
# intel             15
# broadcom           7
# st-ericsson        1
# nvidia             1
# huawei             1
# Name: count, dtype: int64

# %%
df.head(15)
# Out:
#    brand_name                          Name   Price  RAM       OS  storage  \
# 0        vivo                      vivo v50   34999    8  android      128
# 1      realme                 realme p3 pro   21999    8  android      128
# 2      realme            realme 14 pro plus   27999    8  android      128
# 3     samsung      samsung galaxy s25 ultra  129999   12  android      256
# 4        vivo                   vivo t3 pro   22999    8  android      128
# 5    motorola       motorola edge 50 fusion   20299    8  android      128
# 6        moto                      moto g85   18445    8  android      128
# 7     oneplus                   oneplus 13r   42998   12  android      256
# 8        poco                   poco x7 pro   27999    8  android      256
# 9     oneplus          oneplus nord ce 4 5g   22990    8  android      128
# 10       vivo                      vivo v40   36490    8  android      128
# 11    samsung         samsung galaxy m35 5g   14999    6  android      128
# 12    oneplus                    oneplus 13   69998   12  android      256
# 13       iqoo                    iqoo 13 5g   54999   12  android      256
# 14     xiaomi  xiaomi redmi note 14 pro+ 5g   30999    8  android      128
#
#     Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# 0          6000               Yes              Yes      No    Yes
# 1          6000               Yes              Yes      No    Yes
# 2          6000               Yes              Yes      No    Yes
# 3          5000               Yes              Yes     Yes    Yes
# 4          5500               Yes              Yes      No    Yes
# 5          5000               Yes              Yes     Yes    Yes
# 6          5000               Yes              Yes      No    Yes
# 7          6000               Yes              Yes     Yes    Yes
# 8          6550               Yes              Yes     Yes    Yes
# 9          5500               Yes              Yes      No    Yes
# 10         5500               Yes              Yes      No    Yes
# 11         6000               Yes              Yes     Yes    Yes
# 12         6000               Yes              Yes     Yes    Yes
# 13         6000               Yes              Yes     Yes    Yes
# 14         6200               Yes              Yes     Yes    Yes
#
#    processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0       snapdragon         8                   50                 2
# 1       snapdragon         8                   50                 2
# 2       snapdragon         8                   50                 3
# 3       snapdragon         8                  200                 4
# 4       snapdragon         8                   50                 2
# 5       snapdragon         8                   50                 2
# 6       snapdragon         8                   50                 2
# 7       snapdragon         8                   50                 3
# 8         mediatek         8                   50                 2
# 9       snapdragon         8                   50                 2
# 10      snapdragon         8                   50                 2
# 11         samsung         8                   50                 3
# 12      snapdragon         8                   50                 3
# 13      snapdragon         8                   50                 3
# 14      snapdragon         8                   50                 3
#
#     primery_front_camera  num_front_camera  display_size(inch)  \
# 0                     50                 1                6.77
# 1                     16                 1                6.83
# 2                     32                 1                6.83
# 3                     12                 1                6.90
# 4                     16                 1                6.77
# 5                     32                 1                6.67
# 6                     32                 1                6.67
# 7                     16                 1                6.78
# 8                     20                 1                6.67
# 9                     16                 1                6.70
# 10                    50                 1                6.78
# 11                    13                 1                6.60
# 12                    32                 1                6.82
# 13                    32                 1                6.82
# 14                    20                 1                6.67
#
#      display_types processor_cluster
# 0   amoled display        Snapdragon
# 1   amoled display        Snapdragon
# 2     oled display        Snapdragon
# 3   amoled display        Snapdragon
# 4   amoled display        Snapdragon
# 5   amoled display        Snapdragon
# 6   amoled display        Snapdragon
# 7   amoled display        Snapdragon
# 8   amoled display          Mediatek
# 9   amoled display        Snapdragon
# 10  amoled display        Snapdragon
# 11  amoled display        Snapdragon
# 12  amoled display        Snapdragon
# 13  amoled display        Snapdragon
# 14  amoled display        Snapdragon

# %%
df['display_types'].value_counts()
# Out:
# display_types
# lcd display       2010
# amoled display     882
# tft display        209
# oled display       154
# other display        5
# Name: count, dtype: int64

# %%
# List of columns to convert
columns_to_convert = ['has_fast_charging', 'has_fingerprints', 'has_nfc','has_5g']  # Replace with actual column names

# Convert 'Yes' to 1 and 'No' to 0
df[columns_to_convert] = df[columns_to_convert].replace({'Yes': 1, 'No': 0}).astype(int)

# %%
df.head(5)
# Out:
#   brand_name                      Name   Price  RAM       OS  storage  \
# 0       vivo                  vivo v50   34999    8  android      128
# 1     realme             realme p3 pro   21999    8  android      128
# 2     realme        realme 14 pro plus   27999    8  android      128
# 3    samsung  samsung galaxy s25 ultra  129999   12  android      256
# 4       vivo               vivo t3 pro   22999    8  android      128
#
#    Battery_cap  has_fast_charging  has_fingerprints  has_nfc  has_5g  \
# 0         6000                  1                 1        0       1
# 1         6000                  1                 1        0       1
# 2         6000                  1                 1        0       1
# 3         5000                  1                 1        1       1
# 4         5500                  1                 1        0       1
#
#   processor_brand  num_core  primery_rear_camera  Num_Rear_Cameras  \
# 0      snapdragon         8                   50                 2
# 1      snapdragon         8                   50                 2
# 2      snapdragon         8                   50                 3
# 3      snapdragon         8                  200                 4
# 4      snapdragon         8                   50                 2
#
#    primery_front_camera  num_front_camera  display_size(inch)   display_types  \
# 0                    50                 1                6.77  amoled display
# 1                    16                 1                6.83  amoled display
# 2                    32                 1                6.83    oled display
# 3                    12                 1                6.90  amoled display
# 4                    16                 1                6.77  amoled display
#
#   processor_cluster
# 0        Snapdragon
# 1        Snapdragon
# 2        Snapdragon
# 3        Snapdragon
# 4        Snapdragon

# %%
df_numeric = df.select_dtypes(include=['number'])

# Compute correlation with 'Price'
correlation_with_price = df_numeric.corr()['Price']

# Display the result
print(correlation_with_price)
# Out:
# Price                   1.000000
# RAM                     0.538348
# storage                 0.737064
# Battery_cap             0.132871
# has_fast_charging       0.366154
# has_fingerprints       -0.432047
# has_nfc                 0.613217
# has_5g                  0.451548
# num_core                0.119614
# primery_rear_camera     0.287224
# Num_Rear_Cameras        0.313599
# primery_front_camera    0.289566
# num_front_camera        0.163241
# display_size(inch)      0.284860
# Name: Price, dtype: float64

# %%
sns.heatmap(df_numeric.corr())
# Out:
# <Axes: >

# %%
df.drop(columns=['processor_brand'],inplace=True)

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      brand_name                      Name  RAM       OS  storage  Battery_cap  \
# 0          vivo                  vivo v50    8  android      128         6000
# 1        realme             realme p3 pro    8  android      128         6000
# 2        realme        realme 14 pro plus    8  android      128         6000
# 3       samsung  samsung galaxy s25 ultra   12  android      256         5000
# 4          vivo               vivo t3 pro    8  android      128         5500
# ...         ...                       ...  ...      ...      ...          ...
# 3255      ikall               i kall k570    4  android       64         4000
# 3256      Other                   mafe z2    2  android       16         3300
# 3257      Other                   mafe v9    2  android       16         3500
# 3258      Other             marq m3 smart    2  android       32         5000
# 3259      Other       black bear b6 glory    2  android       16         2500
#
#       has_fast_charging  has_fingerprints  has_nfc  has_5g  num_core  \
# 0                     1                 1        0       1         8
# 1                     1                 1        0       1         8
# 2                     1                 1        0       1         8
# 3                     1                 1        1       1         8
# 4                     1                 1        0       1         8
# ...                 ...               ...      ...     ...       ...
# 3255                  0                 1        0       0         8
# 3256                  0                 1        0       0         4
# 3257                  0                 1        0       0         4
# 3258                  0                 1        0       0         8
# 3259                  0                 1        0       0         4
#
#       primery_rear_camera  Num_Rear_Cameras  primery_front_camera  \
# 0                      50                 2                    50
# 1                      50                 2                    16
# 2                      50                 3                    32
# 3                     200                 4                    12
# 4                      50                 2                    16
# ...                   ...               ...                   ...
# 3255                   13                 1                     8
# 3256                    5                 1                     5
# 3257                    5                 1                     5
# 3258                   13                 1                     5
# 3259                    8                 1                     5
#
#       num_front_camera  display_size(inch)   display_types processor_cluster
# 0                    1               6.770  amoled display        Snapdragon
# 1                    1               6.830  amoled display        Snapdragon
# 2                    1               6.830    oled display        Snapdragon
# 3                    1               6.900  amoled display        Snapdragon
# 4                    1               6.770  amoled display        Snapdragon
# ...                ...                 ...             ...               ...
# 3255                 1               6.500     lcd display          Mediatek
# 3256                 1               5.340     lcd display        Snapdragon
# 3257                 1               5.700     lcd display        Snapdragon
# 3258                 1               6.088     lcd display          Mediatek
# 3259                 1               5.500     lcd display          Mediatek
#
# [3260 rows x 18 columns]

# %%
y
# Out:
# 0       10.463075
# 1        9.998752
# 2       10.239924
# 3       11.775282
# 4       10.043206
#           ...
# 3255     8.476163
# 3256     8.575273
# 3257     8.630343
# 3258     8.779404
# 3259     8.699348
# Name: Price, Length: 3260, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#      brand_name                              Name  RAM       OS  storage  \
# 619    micromax            micromax in 2b 6gb ram    6  android       64
# 137        moto               moto g45 5g 8gb ram    8  android      128
# 3095     google              google nexus 6p 64gb    3  android       64
# 1181       iqoo               iqoo neo 6 5g 256gb   12  android      256
# 1981      ikall                       i kall k380    4  android       32
# ...         ...                               ...  ...      ...      ...
# 2347     gionee                         gionee p7    2  android       16
# 1608   micromax  micromax canvas selfie lens q345    1  android        8
# 2541  panasonic                panasonic eluga z1    3  android       32
# 2575      nokia               nokia 5.1 plus 64gb    4  android       64
# 3240      Other                   yuho netra 32gb    4  android       32
#
#       Battery_cap  has_fast_charging  has_fingerprints  has_nfc  has_5g  \
# 619          5000                  0                 1        0       0
# 137          5000                  1                 1        1       1
# 3095         3450                  0                 1        1       0
# 1181         4700                  1                 1        0       1
# 1981         4000                  0                 1        0       0
# ...           ...                ...               ...      ...     ...
# 2347         2300                  0                 1        0       0
# 1608         2800                  0                 1        0       0
# 2541         4000                  0                 1        0       0
# 2575         3060                  0                 1        0       0
# 3240         3300                  0                 1        0       0
#
#       num_core  primery_rear_camera  Num_Rear_Cameras  primery_front_camera  \
# 619          8                   13                 2                     5
# 137          8                   50                 2                    16
# 3095         8                   12                 1                     8
# 1181         8                   64                 3                    16
# 1981         4                   13                 1                     8
# ...        ...                  ...               ...                   ...
# 2347         4                    8                 1                     5
# 1608         8                    8                 1                     5
# 2541         8                   13                 2                     8
# 2575         8                   13                 2                     8
# 3240         8                   13                 1                    13
#
#       num_front_camera  display_size(inch)   display_types processor_cluster
# 619                  1                6.52     lcd display            Others
# 137                  1                6.50     lcd display        Snapdragon
# 3095                 1                5.70  amoled display        Snapdragon
# 1181                 1                6.62  amoled display        Snapdragon
# 1981                 1                7.12     lcd display        Snapdragon
# ...                ...                 ...             ...               ...
# 2347                 1                5.00     lcd display          Mediatek
# 1608                 1                5.00     lcd display          Mediatek
# 2541                 1                6.19     lcd display          Mediatek
# 2575                 1                5.86     lcd display          Mediatek
# 3240                 1                6.10     lcd display          Mediatek
#
# [2771 rows x 18 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2771 entries, 619 to 3240
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            2771 non-null   object
#  1   Name                  2771 non-null   object
#  2   RAM                   2771 non-null   int64
#  3   OS                    2771 non-null   object
#  4   storage               2771 non-null   int64
#  5   Battery_cap           2771 non-null   int64
#  6   has_fast_charging     2771 non-null   int64
#  7   has_fingerprints      2771 non-null   int64
#  8   has_nfc               2771 non-null   int64
#  9   has_5g                2771 non-null   int64
#  10  num_core              2771 non-null   int64
#  11  primery_rear_camera   2771 non-null   int64
#  12  Num_Rear_Cameras      2771 non-null   int64
#  13  primery_front_camera  2771 non-null   int64
#  14  num_front_camera      2771 non-null   int64
#  15  display_size(inch)    2771 non-null   float64
#  16  display_types         2771 non-null   object
#  17  processor_cluster     2771 non-null   object
# dtypes: float64(1), int64(12), object(5)
# memory usage: 411.3+ KB

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

step2 = LinearRegression()

pipe_lr = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe_lr.fit(X_train,y_train)

y_pred = pipe_lr.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.7705747446359702
# MAE 0.2876307920819491
# RMSE 0.3901337675246068

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe_rd = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe_rd.fit(X_train,y_train)

y_pred = pipe_rd.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.8136938616487709
# MAE 0.25110087691482047
# RMSE 0.35156571194487907

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe_ls = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe_ls.fit(X_train,y_train)

y_pred = pipe_ls.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.8142110678586715
# MAE 0.250829815639096
# RMSE 0.3510773803664212

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe_knn = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe_knn.fit(X_train,y_train)

y_pred = pipe_knn.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.6888757277373068
# MAE 0.3082279307920422
# RMSE 0.4543179298195987

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe_svr = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe_svr.fit(X_train,y_train)

y_pred = pipe_svr.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.7532427436334957
# MAE 0.2780437489399922
# RMSE 0.40460187984691304

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=4,
                              max_samples=0.6,
                              max_features=0.75,
                              max_depth=20)

pipe_rf = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe_rf.fit(X_train,y_train)

y_pred = pipe_rf.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('RMSE', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.8561658065455359
# MAE 0.21331021268625888
# RMSE 0.30890433361057157

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve

# Define a threshold for classification (e.g., median of training data)
threshold = np.median(y_train)

# Convert y_test into binary labels
y_test_binary = (y_test > threshold).astype(int)

# Store model names and their trained pipeline objects
models = {
    "Linear Regression": pipe_lr,  # Update these if names are different
    "Ridge Regression": pipe_rd,
    "Lasso Regression": pipe_ls,
    "KNN Regressor": pipe_knn,
    "SVR":pipe_svr,
    "RandomForest":pipe_rf,
}

plt.figure(figsize=(8, 6))

for model_name, model in models.items():
    y_pred_prob = model.predict(X_test)  # Get predicted values
    y_pred_class = (y_pred_prob > threshold).astype(int)  # Convert predictions to binary
    
    # Compute AUC and ROC Curve
    fpr, tpr, _ = roc_curve(y_test_binary, y_pred_prob)  # Use binarized y_test
    auc_score = roc_auc_score(y_test_binary, y_pred_prob)
    
    # Plot the ROC Curve
    plt.plot(fpr, tpr, label=f"{model_name} (AUC = {auc_score:.2f})")

# Plot reference line
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("AUC-ROC Curve for Regression Models Converted to Classification")
plt.legend()

# Save the figure as an SVG file
plt.savefig('AUC_ROC_Curve_mobile.svg', format='svg')

plt.show()

# %%
from sklearn.ensemble import StackingRegressor

# %%
final_estimator = Ridge()

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

base_models = [
    ('linear', Pipeline(steps=[
        ('step1', step1), 
        ('step2', LinearRegression())
    ])),
    ('ridge', Pipeline(steps=[
        ('step1', step1),
        ('step2', Ridge(alpha=10))
    ])),
    ('lasso', Pipeline(steps=[
        ('step1', step1),
        ('step2', Lasso(alpha=0.001))
    ])),
    ('random', Pipeline(steps=[
        ('step1', step1),
        ('step2', RandomForestRegressor(n_estimators=100,
                              random_state=4,
                              max_samples=0.6,
                              max_features=0.75,
                              max_depth=20))
    ])),
    ('svr', Pipeline(steps=[
        ('step1', step1),
        ('step2', SVR(kernel='rbf',C=10000,epsilon=0.1))
    ]))
]
# Define your meta model (Ridge)
meta_model = Ridge(alpha=0.1)

# Set up the Stacking Regressor
stacked_model = StackingRegressor(estimators=base_models, final_estimator=meta_model)

# Optionally, you can wrap this in a pipeline if you need preprocessing
# Here we use a simple StandardScaler for preprocessing
pipeline = Pipeline(steps=[
    ('step1', step1),  # Scaling for the base models
    ('stacked_model', stacked_model)
])

# Split your data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# Fit the model
pipeline.fit(X_train, y_train)

# Make predictions
y_pred = pipeline.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

#r2 score evaluate
r2 = r2_score(y_test, y_pred)

# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)

# Output the results
print(f"R² Score: {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f'Mean Squared Error: {mse}')
# Out:
# R² Score: 0.8603683101252368
# Mean Absolute Error (MAE): 0.2103327948711306
# Mean Squared Error: 0.09263387973335095

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[0,1,3,16,17])
],remainder='passthrough')

base_models = [
    ('linear', Pipeline(steps=[
        ('step1', step1), 
        ('step2', LinearRegression())
    ])),
    ('ridge', Pipeline(steps=[
        ('step1', step1),
        ('step2', Ridge(alpha=10))
    ])),
    ('lasso', Pipeline(steps=[
        ('step1', step1),
        ('step2', Lasso(alpha=0.001))
    ])),
    ('random', Pipeline(steps=[
        ('step1', step1),
        ('step2', RandomForestRegressor(n_estimators=100,
                              random_state=4,
                              max_samples=0.6,
                              max_features=0.75,
                              max_depth=20))
    ])),
    ('svr', Pipeline(steps=[
        ('step1', step1),
        ('step2', SVR(kernel='rbf',C=10000,epsilon=0.1))
    ]))
]
# Define your meta model (RandomForest)
meta_model = RandomForestRegressor(random_state=2)

# Set up the Stacking Regressor
stacked_model = StackingRegressor(estimators=base_models, final_estimator=meta_model)

# Optionally, you can wrap this in a pipeline if you need preprocessing
# Here we use a simple StandardScaler for preprocessing
pipeline = Pipeline(steps=[
    ('step1', step1),  # Scaling for the base models
    ('stacked_model', stacked_model)
])

# Split your data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# Fit the model
pipeline.fit(X_train, y_train)

# Make predictions
y_pred = pipeline.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

#r2 score evaluate
r2 = r2_score(y_test, y_pred)

# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)

# Output the results
print(f"R² Score: {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f'Mean Squared Error: {mse}')
# Out:
# R² Score: 0.8435733440922548
# Mean Absolute Error (MAE): 0.22955655088232116
# Mean Squared Error: 0.10377592682180467

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# Assume your stacked model is named: stacked_model
# And your features and target are: X, y

# R² Score Cross-validation
r2_scores = cross_val_score(stacked_model, X, y, cv=5, scoring='r2')
print("R² Scores (CV):", r2_scores)
print("Mean R² Score:", np.mean(r2_scores))

# MAE Cross-validation
mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)
mae_scores = cross_val_score(stacked_model, X, y, cv=5, scoring=mae_scorer)
print("MAE Scores (CV):", -mae_scores)  # Negate to get positive values
print("Mean MAE Score:", -np.mean(mae_scores))

# MSE Cross-validation
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
mse_scores = cross_val_score(stacked_model, X, y, cv=5, scoring=mse_scorer)
print("MSE Scores (CV):", -mse_scores)
print("Mean MSE Score:", -np.mean(mse_scores))
# Out:
# R² Scores (CV): [0.77743258 0.83829376 0.86763249 0.80069587 0.8407402 ]
# Mean R² Score: 0.824958978212118
# MAE Scores (CV): [0.23906725 0.21899529 0.22138706 0.25156232 0.20581412]
# Mean MAE Score: 0.22736520791162712
# MSE Scores (CV): [0.11294168 0.08820642 0.08800297 0.11234275 0.08285406]
# Mean MSE Score: 0.09686957717216432

# %%
stacking_regressor = StackingRegressor(
    estimators=[
        ('ridge', pipe_rd),
        ('lasso', pipe_ls),
        ('svr', pipe_svr),
        ('linear', pipe_lr),
        ('random',pipe_rf)
    ],
    final_estimator=final_estimator,
    passthrough=False,  # if True, raw features are also passed to the final estimator
    n_jobs=-1
)

# Fit and evaluate
stacking_regressor.fit(X_train, y_train)
y_pred = stacking_regressor.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MAE: 0.2108345483655386
# MSE: 0.09372640670482346
# R2: 0.8587214894620023

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define your results as a dictionary
results = {
    'Linear': {'R2': 0.77,'MAE': 0.28,'RMSE': 0.39},
    'Lasso': {'R2':0.81,'MAE':0.25,'RMSE':0.35},
    'Ridge': {'R2':0.81,'MAE': 0.25,'RMSE': 0.35},
    'SVR': {'R2':0.75,'MAE':0.27,'RMSE':0.40},
    'RandomForest': {'R2': 0.85,'MAE': 0.21,'RMSE': 0.31},
    'Stacked_Model': {'R2': 0.86,'MAE': 0.21,'RMSE': 0.09}
}

# Convert to DataFrame
df = pd.DataFrame(results).T.reset_index().rename(columns={'index': 'Model'})

# Melt for plotting
df_melted = df.melt(id_vars='Model', var_name='Metric', value_name='Score')

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=df_melted, x='Model', y='Score', hue='Metric')
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xlabel('Model')
plt.xticks(rotation=15)
plt.legend(title='Metric')
plt.tight_layout()

# Save the figure as an SVG file
plt.savefig('model_performance_comparison_mobile.svg', format='svg')

plt.show()
